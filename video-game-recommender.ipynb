# %%
import pandas as pd
import numpy as np
import nltk
# nltk.download('omw-1.4')
# nltk.download('all')

# %%
df = pd.read_csv('../input/top-video-games-19952021-metacritic/all_games.csv')
df.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score user_review
# 0  As a young boy, Link is tricked by Ganondorf, ...          99         9.1
# 1  As most major publishers' development efforts ...          98         7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98         7.7
# 3  This is a tale of souls and swords, transcendi...          98         8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98         7.9

# %%
df = df.dropna()
df.reset_index(drop=True, inplace=True)

# %%
df.describe()
# Out:
#          meta_score
# count  18686.000000
# mean      70.656481
# std       12.233243
# min       20.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max       99.000000

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

def nlp(df, text):
    #dummy column
    df['dummy'] = df[text].astype(str).str.lower()
    
    token_summ = (word_tokenize(post) for post in df['dummy'])
#     df['token_summ'] = [i for i in token_summ]
    
    reg = re.compile('(@[a-z0-9]+)|([^0-9a-z \t])|(\w+:\/\/\S+)')
    
    no_punc = []
    
    for filt in token_summ:
        review = []
        for token in filt:
            new_token = reg.sub('', token)
            if new_token != '':
                review.append(new_token)
        no_punc.append(review)
    
    no_stop = []
    
    for post in no_punc:
        new_term_vector = []
        for word in post:
            if not word in stopwords.words('english'):
                new_term_vector.append(word)
        no_stop.append(new_term_vector)
    
    pstem = PorterStemmer()
    wlem = WordNetLemmatizer()
    
    preproc_text = []
    
    for text in no_stop:
        final_text = []
        for word in text:
            pstem.stem(word)
            final_text.append(wlem.lemmatize(word))
        preproc_text.append(final_text)
        

    df['proc_summary'] = pd.Series(preproc_text)
    df.drop('dummy', axis=1, inplace=True)
    return df
    
proc_data = nlp(df, 'summary')

# %%
proc_data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
# 5                    Super Mario Galaxy             Wii   November 12, 2007
# 6                  Super Mario Galaxy 2             Wii        May 23, 2010
# 7                 Red Dead Redemption 2        Xbox One    October 26, 2018
# 8                    Grand Theft Auto V        Xbox One   November 18, 2014
# 9                    Grand Theft Auto V   PlayStation 3  September 17, 2013
#
#                                              summary  meta_score user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99         9.1
# 1  As most major publishers' development efforts ...          98         7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98         7.7
# 3  This is a tale of souls and swords, transcendi...          98         8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98         7.9
# 5  [Metacritic's 2007 Wii Game of the Year] The u...          97         9.1
# 6  Super Mario Galaxy 2, the sequel to the galaxy...          97         9.1
# 7  Developed by the creators of Grand Theft Auto ...          97         8.0
# 8  Grand Theft Auto 5 melds storytelling and game...          97         7.9
# 9  Los Santos is a vast, sun-soaked metropolis fu...          97         8.3
#
#                                         proc_summary
# 0  [young, boy, link, tricked, ganondorf, king, g...
# 1  [major, publisher, development, effort, shift,...
# 2  [metacritic, 2008, ps3, game, year, also, know...
# 3  [tale, soul, sword, transcending, world, histo...
# 4  [metacritic, 2008, xbox, 360, game, year, also...
# 5  [metacritic, 2007, wii, game, year, ultimate, ...
# 6  [super, mario, galaxy, 2, sequel, galaxyhoppin...
# 7  [developed, creator, grand, theft, auto, v, re...
# 8  [grand, theft, auto, 5, meld, storytelling, ga...
# 9  [los, santos, vast, sunsoaked, metropolis, ful...

# %%
proc_data.reset_index(drop=True, inplace=True)
proc_data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99         9.1
# 1  As most major publishers' development efforts ...          98         7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98         7.7
# 3  This is a tale of souls and swords, transcendi...          98         8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98         7.9
#
#                                         proc_summary
# 0  [young, boy, link, tricked, ganondorf, king, g...
# 1  [major, publisher, development, effort, shift,...
# 2  [metacritic, 2008, ps3, game, year, also, know...
# 3  [tale, soul, sword, transcending, world, histo...
# 4  [metacritic, 2008, xbox, 360, game, year, also...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform([str(i) for i in proc_data['proc_summary']])
tfidf_matrix.shape
# Out:
# (10, 368)

# %%
tfidf_matrix
# Out:
# <10x368 sparse matrix of type '<class 'numpy.float64'>'
# 	with 471 stored elements in Compressed Sparse Row format>

# %%
# tfidf.get_feature_names()

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/130662056.py in <module>
#       1 from sklearn.metrics.pairwise import linear_kernel
# ----> 2 cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
#       3 cosine_sim
#
# NameError: name 'tfidf_matrix' is not defined

# %%
indices = pd.Series(proc_data.index, index=proc_data['name']).drop_duplicates()
indices
# Out:
# name
# The Legend of Zelda: Ocarina of Time    0
# Tony Hawk's Pro Skater 2                1
# Grand Theft Auto IV                     2
# SoulCalibur                             3
# Grand Theft Auto IV                     4
# Super Mario Galaxy                      5
# Super Mario Galaxy 2                    6
# Red Dead Redemption 2                   7
# Grand Theft Auto V                      8
# Grand Theft Auto V                      9
# dtype: int64

# %%
def recommend(title, cosine_sim=cosine_sim):
    idx = indices[title]
    
    similarity = list(enumerate(cosine_sim[idx]))
    
    similarity = sorted(similarity, key=lambda x: x[1], reverse=True)
    
    similarity = similarity[1:11]
    
    game_indices = [i[0] for i in similarity]
    
    recs = proc_data['name'].iloc[game_indices]
    
    return recs

# %%
recommend('Pokemon HeartGold Version')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 'Pokemon HeartGold Version'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_27/1410060182.py in <module>
# ----> 1 recommend('Pokemon HeartGold Version')
#
# /tmp/ipykernel_27/2764659249.py in recommend(title, cosine_sim)
#       1 def recommend(title, cosine_sim=cosine_sim):
# ----> 2     idx = indices[title]
#       3
#       4     similarity = list(enumerate(cosine_sim[idx]))
#       5
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Pokemon HeartGold Version'
